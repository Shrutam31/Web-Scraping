# %%
import pandas as pd
import requests

# The URL
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36'
}

try:
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # This will raise an error for bad responses (4xx or 5xx)

    tables = pd.read_html(response.text)

    # On this Wikipedia page, the main list is the first table (index 0)
    df = tables[0]

    print("Successfully scraped the table:")
    print(df)

except requests.exceptions.HTTPError as err:
    print(f"HTTP Error: {err}")
except Exception as err:
    print(f"An error occurred: {err}")
# Out:
# Successfully scraped the table:
#     Rank                     Name                    Industry  \
# 0      1                  Walmart                      Retail
# 1      2                   Amazon  Retail and cloud computing
# 2      3       UnitedHealth Group                  Healthcare
# 3      4                    Apple        Electronics industry
# 4      5               CVS Health                  Healthcare
# ..   ...                      ...                         ...
# 95    96         General Dynamics       Aerospace and defense
# 96    97                Coca-Cola                    Beverage
# 97    98                     TIAA                  Financials
# 98    99  The Travelers Companies                   Insurance
# 99   100                Eli Lilly     Pharmaceutical industry
#
#     Revenue (USD millions) Revenue growth  Employees              Headquarters
# 0                   680985           5.1%    2100000     Bentonville, Arkansas
# 1                   637959          11.0%    1556000       Seattle, Washington
# 2                   400278           7.7%     400000     Minnetonka, Minnesota
# 3                   391035           2.0%     164000     Cupertino, California
# 4                   372809           4.2%     259500  Woonsocket, Rhode Island
# ..                     ...            ...        ...                       ...
# 95                   47716          12.9%     117000          Reston, Virginia
# 96                   47061           2.9%      69700          Atlanta, Georgia
# 97                   46946           2.6%      15623   New York City, New York
# 98                   46423          12.2%      34000   New York City, New York
# 99                   45043          32.0%      47000     Indianapolis, Indiana
#
# [100 rows x 7 columns]
# An error occurred: 'NoneType' object is not subscriptable
# /tmp/ipython-input-3352483442.py:19: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(response.text)

# %%
df.to_csv('web_scrapping.csv')

# %%
# Now Scarpping the second Table
df = tables[1]
df
# Out:
#    Rank                                Name                       Industry  \
# 0     1                             Cargill                  Food industry
# 1     2                     Koch Industries                   Conglomerate
# 2     3                Publix Super Markets                         Retail
# 3     4                  Mars, Incorporated                  Food industry
# 4     5                               H-E-B                         Retail
# 5     6                      Reyes Holdings                    Wholesaling
# 6     7                 Enterprise Holdings                     Car rental
# 7     8               C&S Wholesale Grocers                    Wholesaling
# 8     9                              Love's  Petroleum industry and Retail
# 9    10  Southern Glazer's Wine and Spirits                  Food industry
#
#    Revenue (USD billions)  Employees             Headquarters
# 0                   177.0     160000    Minnetonka, Minnesota
# 1                   125.0     120000          Wichita, Kansas
# 2                    54.5     250000        Lakeland, Florida
# 3                    47.0     140000         McLean, Virginia
# 4                    43.6     145000       San Antonio, Texas
# 5                    40.0      36000       Rosemont, Illinois
# 6                    35.0      90000        Clayton, Missouri
# 7                    34.7      15000     Keene, New Hampshire
# 8                    26.5      40000  Oklahoma City, Oklahoma
# 9                    26.0      24000         Miramar, Florida

# %%
df.to_csv('second_table.csv')
